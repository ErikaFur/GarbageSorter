# %% [markdown]
# # **Data processing**
# Here we explore the available datasets, try to get some insights and preprocess the data for our project.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### **1.** [**Garbage Classification dataset 1**](https://www.kaggle.com/datasets/asdasdasasdas/garbage-classification/code) **(Kaggle)**
#
# The Garbage Classification Dataset contains 6 classifications: cardboard (393), glass (491), metal (400), paper(584), plastic (472) and trash(127).

# %%
# !unzip '/content/drive/MyDrive/Practical ML and DL/Project/D1.2/Datasets/Dataset1.zip'

# %% [markdown]
# The first dataset consists of:
# 1. folders with garbage .jpg photos and
# 2. .txt files with annotated names of photos.
#
# There are one file with annotated data from 0 to 5 according to the classes, one file with annotated data from 1 to 6 according to classes and grouped by class, 3 files with annotated data from 1 to 6 according to classes shuffled (train, test and validation sets).

# %%
def show(path):
  image = cv2.imread(path, cv2.IMREAD_COLOR)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.imshow(image)

# %% [markdown]
# Let's look at the data inside:

# %%
show('/content/garbage classification/Garbage classification/cardboard/cardboard1.jpg')

# %%
show('/content/garbage classification/Garbage classification/glass/glass1.jpg')

# %%
show('/content/garbage classification/Garbage classification/metal/metal1.jpg')

# %%
show('/content/garbage classification/Garbage classification/paper/paper1.jpg')

# %%
show('/content/garbage classification/Garbage classification/plastic/plastic1.jpg')

# %%
show('/content/garbage classification/Garbage classification/trash/trash1.jpg')

# %% [markdown]
# Our model will classify the garbage into 5 classes:
# * paper+cardboard
# * plastic
# * glass
# * metal
# * other (non-classified)
#
# So, for our model we will use photos from this dataset and probably .txt annotations too.

# %% [markdown]
# ### **2. [Garbage Classification dataset 2](https://www.kaggle.com/datasets/mostafaabla/garbage-classification) (Kaggle)**
#
# This dataset has 15,150 images from 12 different classes of household garbage; paper, cardboard, biological, metal, plastic, green-glass, brown-glass, white-glass, clothes, shoes, batteries, and trash.
#
# * The clothes category and 22% of the shoes' category were obtained from the Clothing dataset https://www.kaggle.com/agrigorev/clothing-dataset-full
# * Around 29% of the other 9 classes combined was collected from the Garbage Classification dataset https://www.kaggle.com/asdasdasasdas/garbage-classification
# * All the rest of the images were obtained using Web Scrapping.

# %%
# !unzip '/content/drive/MyDrive/Practical ML and DL/Project/D1.2/Datasets/Dataset2.zip'
